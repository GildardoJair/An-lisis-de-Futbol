# %%
#Importamos las librerias necesarias
#Importamos nuestras librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns   
#Procesado y Modelado
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats
import statsmodels as sms
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.stattools import jarque_bera
# configuración de matplotlib
plt.rcParams['image.cmap']="bwr"
plt.rcParams['figure.dpi']="200"
plt.rcParams['savefig.bbox']="tight"
plt.style.use(r"C:\Users\gilda\Desktop\Python\Data Science\datasets\neon_dark")

# configuración de warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# El objetivo es crear un data set apartir de diferentes equipos y temporadas con la finalidad de poder aplicar técnicas de machine learning e inteligencia artificial

# %%
URL_Barca_2024_2025 = 'https://fbref.com/es/equipos/206d90db/Estadisticas-de-Barcelona'
URL_Barca_2023_2024 = 'https://fbref.com/es/equipos/206d90db/2023-2024/Estadisticas-de-Barcelona'
URL_Barca_2022_2023 = 'https://fbref.com/es/equipos/206d90db/2022-2023/Estadisticas-de-Barcelona'
URL_Madrid_2024_2025 = 'https://fbref.com/es/equipos/53a2f082/Estadisticas-de-Real-Madrid'
URL_Madrid_2023_2024 = 'https://fbref.com/es/equipos/53a2f082/2023-2024/Estadisticas-de-Real-Madrid'
URL_Madrid_2022_2023 = 'https://fbref.com/es/equipos/53a2f082/2022-2023/Estadisticas-de-Real-Madrid'
URL_Atletico_2024_2025 = 'https://fbref.com/es/equipos/db3b9613/Estadisticas-de-Atletico-Madrid'
URL_Atletico_2023_2024 = 'https://fbref.com/es/equipos/db3b9613/2023-2024/Estadisticas-de-Atletico-Madrid'
URL_Atletico_2022_2023 = 'https://fbref.com/es/equipos/db3b9613/2022-2023/Estadisticas-de-Atletico-Madrid'

# %%
df_Barca_2024_2025 = pd.read_html(URL_Barca_2024_2025)[0]
df_Barca_2023_2024 = pd.read_html(URL_Barca_2023_2024)[0]
df_Barca_2022_2023 = pd.read_html(URL_Barca_2022_2023)[0]
df_Madrid_2024_2025 = pd.read_html(URL_Madrid_2024_2025)[0]
df_Madrid_2023_2024 = pd.read_html(URL_Madrid_2023_2024)[0]
df_Madrid_2022_2023 = pd.read_html(URL_Madrid_2022_2023)[0]
df_Atletico_2024_2025 = pd.read_html(URL_Atletico_2024_2025)[0]
df_Atletico_2023_2024 = pd.read_html(URL_Atletico_2023_2024)[0]
df_Atletico_2022_2023 = pd.read_html(URL_Atletico_2022_2023)[0]

# %% [markdown]
# # Temporada 2024-2025

# %%
#Eliminamos la primera y últimas dos filas del dataframe
df_Barca_2024_2025 = df_Barca_2024_2025.iloc[:-2, :] #Se eliminan las dos últimas filas ya que no son de interés
df_Barca_2024_2025.columns = df_Barca_2024_2025.columns.droplevel(0) #Se eliminan la primera fila
#Se eliminan las 10 últimas columnas ya que no son de interés
df_Barca_2024_2025 = df_Barca_2024_2025.iloc[:, :-11]
df_Barca_2024_2025= df_Barca_2024_2025.drop(columns=['npxG+xAG'])
df_Barca_2024_2025.head()
# Out:
#               Jugador    País   Posc    Edad  PJ  Titular     Mín  90 s  Gls.  \
# 0        Jules Koundé  fr FRA     DF  26-140  29       26  2335.0  25.9   2.0
# 1            Raphinha  br BRA  DL,CC  28-108  27       26  2218.0  24.6  13.0
# 2  Robert Lewandowski  pl POL     DL  36-223  28       26  2209.0  24.5  25.0
# 3               Pedri  es ESP     CC  22-127  28       26  2185.0  24.3   4.0
# 4         Pau Cubarsí  es ESP     DF  18-069  28       24  2155.0  23.9   0.0
#
#    Ass  ...   TP  TPint   TA   TR    xG  npxG   xAG  PrgC   PrgP   PrgR
# 0  3.0  ...  0.0    0.0  3.0  0.0   1.7   1.7   3.8  40.0  146.0  168.0
# 1  8.0  ...  1.0    1.0  3.0  0.0  14.4  13.6  10.6  74.0  114.0  262.0
# 2  2.0  ...  3.0    4.0  1.0  0.0  24.0  20.8   2.3  24.0   44.0  143.0
# 3  4.0  ...  0.0    0.0  2.0  0.0   2.0   2.0   5.7  70.0  249.0   97.0
# 4  3.0  ...  0.0    0.0  3.0  0.0   0.7   0.7   1.6  23.0  167.0    5.0
#
# [5 rows x 22 columns]

# %%
# Aplica esto SOLO a df1 antes de concatenar
df_Barca_2024_2025['Edad'] = df_Barca_2024_2025['Edad'].str.split('-').str[0]  # Toma solo el número antes del guion
df_Barca_2024_2025['Edad'] = pd.to_numeric(df_Barca_2024_2025['Edad'], errors='coerce')  # Convierte a número

# %%
df_Barca_2024_2025 =df_Barca_2024_2025.dropna() #Eliminamos los valores nulos
